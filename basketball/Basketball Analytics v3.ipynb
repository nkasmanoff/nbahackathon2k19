# %% [markdown]
# First notebook for basketball analytics section, can hopefully begin by flagging end of possestion stuff.
#
#
# I uploaded the code used by Sarang to calculate the +/- of any player during a game, but it appears not to work exactly the same as before. I'm not sure why, but I better figure that out, how these functions work again, and then perform a similar operation for BPM.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
# coding: utf-8

# In[1]:

import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)


# In[2]:

def substitution_correction(subs,lineup):
    """Go through a game dataframe. Correct and confirm that the
    substitution team assignments are correct.

    Parameters
    ----------

    subs : df
        pandas dataframe of every substitution to occur during a game.

    lineups : df
        provided data, the lineup for that given game

    Returns
    -------

    subs : df
        Corrected version of subs where the
        team assignments for the player are correct.

    """
    #Step 1 of cleaning, delete extra cols and make a person1 col to merge w/ subs.
    lineup['Person1'] = lineup['Person_id']
    del lineup['Period'],lineup['status'],lineup['Game_id']
    del subs['Team_id']
    first = pd.merge(subs, lineup,
        on = ['Person1'], how = 'left')
    
    first.drop_duplicates(inplace=True)
    del lineup['Person1']

    weird = first[['Person2','Team_id']]  #now act in parralel. make a df of "first" with only nan cols.
                                    #and weird has every col except but just p2 and team.
    nanmask = first['Team_id'].isna().values
    weird = weird[~nanmask]

    nanfirst = first[nanmask]
    nanfirst.dropna(axis=1,inplace=True) #remove columns to be added back soon
    weird['Person1'] = weird['Person2']
    weird = weird[['Person1','Team_id']]


    second = pd.merge(nanfirst, weird,
        on = ['Person1'], how = 'left')
    del first['Person_id']
    second.drop_duplicates(inplace=True) #remove extraneious cols and shove this into the first[nanmask]!
    if len(second.values) >0:
        first[nanmask] = second.values #and that's it.


    subs = first[['Game_id','Event_Num','Event_Msg_Type','Period','WC_Time','PC_Time','Action_Type','Option1','Option2',
                'Option3','Team_id','Person1','Person2','Team_id_type','Event_Msg_Type_Description']]

    corrected_subs = subs
    return corrected_subs



def sub(playersin, bench, substitution):
    """Function to calculate plus/minus for individuals when they subout
    and calculate difference when subbing in.

    Parameters
    ----------

    playersin : df
        dataframe of players on the court, has columns 'Team_id', 'Person_id', diffin
        and 'pm'

    bench : df
        dataframe of players on the bench, has columns 'Team_id', 'Person_id', diffin
        and 'pm'

    substitution : df
        a single row from the play-by-play dataframe for which the substitution occurs
        Event Msg Type: 8

    Returns :
    playersin, bench
    -------
    """

    teamid = substitution['Team_id']
    suboutID = substitution['Person1']
    subinID = substitution['Person2']
    score1 = substitution['score_x']
    score2 = substitution['score_y']

    if teamid == teams[0]:
        diff = score1 - score2
    else:
        diff = score2 - score1

    suboutindex = (playersin['Person_id'] == suboutID)
    playersin.loc[suboutindex,'pm'] = playersin.loc[suboutindex,'pm']     + diff - playersin.loc[suboutindex,'diffin']

    if ~bench['Person_id'].str.contains(subinID).any(): # if the player isn't in the "bench" df,
                                                        # ie. hasn't already appeared in the game
            playersin = playersin.append(
            {'Team_id': teamid, 'Person_id':subinID, 'diffin':diff, 'pm':0},
            ignore_index = True)
    else: # if he's in the "bench" df already
        playersin = playersin.append(bench.loc[bench['Person_id'] == subinID])
        bench = bench.loc[~(bench['Person_id'] == subinID)]

    bench = bench.append(playersin.loc[playersin['Person_id'] == suboutID])
    playersin = playersin.loc[~(playersin['Person_id'] == suboutID)]

    # set the score difference for new player
    playersin.loc[playersin['Person_id'] == subinID, 'diffin'] = diff

    return playersin, bench


# In[4]:

def startperiod(playersin, bench, startrow):
    """ Function to switch out players at the start of the period
    and calculate the score difference coming in

    Parameters
    ----------

    playersin : df
        dataframe of players on the court, has columns 'Team_id', 'Person_id', diffin
        and 'pm'

    bench : df
        dataframe of players on the bench, has columns 'Team_id', 'Person_id', diffin
        and 'pm'

    startrow : df
        a single row from the play-by-play dataframe for which the start of the period occurs
        Event Msg Type: 12

    Returns 
    -------

    playersin, bench
    """

    score1 = startrow['score_x']
    score2 = startrow['score_y']
    diff = score1 - score2
    period = startrow['Period']

    # identify who is coming in at the start of the period
    periodstarters = lineup.loc[(lineup['Game_id'] == game) & (lineup['Period'] == period)]
    allplayers = pd.concat([bench, playersin])

    # allocate players going in and those on the bench
    playersintemp = pd.concat([
            playersin.loc[playersin['Person_id'].isin(periodstarters['Person_id'])], \
            bench.loc[bench['Person_id'].isin(periodstarters['Person_id'])]
        ])
    benchtemp = pd.concat([
            bench.loc[~bench['Person_id'].isin(periodstarters['Person_id'])], \
            playersin.loc[~playersin['Person_id'].isin(periodstarters['Person_id'])]
        ])

    playersin = playersintemp
    bench = benchtemp

    # check to see if there are players first coming in at the start of the period
    check = periodstarters['Person_id'].isin(allplayers['Person_id'])
    if ~check.all():
        newplayers = periodstarters.loc[~check]
        for index,newplayer in newplayers.iterrows():
            playersin = playersin.append(
                {'Team_id': newplayer['Team_id'],
                 'Person_id': newplayer['Person_id'],
                 'diffin':0,
                 'pm':0},
                ignore_index = True)

    # set the score difference for all players at the start of the period
    playersin.loc[playersin['Team_id'] == teams[0],'diffin'] = diff
    playersin.loc[playersin['Team_id'] == teams[1],'diffin'] = -diff


    return playersin, bench


def endperiod(playersin, bench, endrow):
    """ Function to calculate the plus minus for everyone at the end of the period

    Parameters
    ----------

    playersin : df
        dataframe of players on the court, has columns 'Team_id', 'Person_id', diffin
        and 'pm'

    bench : df
        dataframe of players on the bench, has columns 'Team_id', 'Person_id', diffin
        and 'pm'

    startrow : df
        a single row from the play-by-play dataframe for which the start of the period occurs
        Event Msg Type: 12

    Returns :
    playersin, bench
    -------
    """

    score1 = endrow['score_x']
    score2 = endrow['score_y']
    diff = score1 - score2

    # calculate plus minus for everyone at the end of the period
    playersin.loc[playersin['Team_id'] == teams[0], 'pm']         = playersin.loc[playersin['Team_id'] == teams[0],'pm']         + diff - playersin.loc[playersin['Team_id'] == teams[0],'diffin']
    playersin.loc[playersin['Team_id'] == teams[1], 'pm']         = playersin.loc[playersin['Team_id'] == teams[1],'pm']         - diff - playersin.loc[playersin['Team_id'] == teams[1],'diffin']

    return playersin, bench

# %%
#load in data. 
pbp = pd.read_csv('Basketball Analytics/Play_by_Play.txt',delimiter='\t')
lineup = pd.read_csv('Basketball Analytics/Game_Lineup.txt',delimiter='\t')
ec = pd.read_csv('Basketball Analytics/Event_Codes.txt',delimiter = '\t')


pbp = pd.read_csv('Basketball Analytics/Play_by_Play.txt',delimiter='\t')
lineup = pd.read_csv('Basketball Analytics/Game_Lineup.txt',delimiter='\t')
codes = pd.read_csv('Basketball Analytics/Event_Codes.txt',delimiter = '\t')

# %%
pms = pd.DataFrame([])

#pt 2. isolate one game instance
# indentify sample games, loop through all
sample_games = pbp['Game_id'].unique()
######Loop and test sub function here ######
for game_num in range(len(sample_games))[0:1]:
    game = sample_games[game_num] # for now, not iterative.
    print("game id: ", game)
    print("game num: ",game_num)
    teams = lineup.loc[lineup['Game_id'] == game]['Team_id'].unique()
    
    pbp_singlegame = pbp.loc[pbp['Game_id'] == sample_games[game_num]].sort_values(['Period','PC_Time','Event_Msg_Type','WC_Time','Event_Num'],
        ascending=[True,False,True,True,True])
    pbp_singlegame = pbp_singlegame.merge( codes,
        on = ['Event_Msg_Type', 'Action_Type'], how = 'left')
    pbp_relevant = pbp_singlegame #.loc[(pbp_singlegame['Event_Msg_Type'] == 1) |
        #(pbp_singlegame['Event_Msg_Type'] == 3) | (pbp_singlegame['Event_Msg_Type'] == 8) |
       # (pbp_singlegame['Event_Msg_Type'] == 12) | (pbp_singlegame['Event_Msg_Type'] == 13)]
   # del pbp_relevant['Action_Type_Description']
  
    starting_lineup = lineup.loc[(lineup['Game_id'] == game)] #starting lineup of the game
    subsmask = pbp_relevant['Event_Msg_Type'] == 8
    subs = pbp_relevant[subsmask] #dataframe of all substitutions. 
    playersin = pd.DataFrame(starting_lineup.loc[(starting_lineup['Period'] == 1),['Team_id','Person_id']])

    subs_correct = substitution_correction(subs,starting_lineup)
    pbp_relevant[subsmask] =  subs_correct

    
    playersin['ortg'] = 0 #initialize offensive rating
    playersin['diffin'] = playersin['pm'] = 0
    bench = pd.DataFrame(columns = ['Team_id', 'Person_id', 'diffin', 'pm','ortg']) #again added that column.


    pbp_relevant.loc[(pbp_relevant['Event_Msg_Type'] == 3)&(pbp_relevant['Option1'] != 1), 'Option1'] = 0
    pbp_relevant['score'] = pbp_relevant.groupby('Team_id', axis = 0)['Option1'].cumsum() #calulate score of each team throughout the game. 
    team1score = pbp_relevant.loc[pbp_relevant.iloc[:,10] == teams[0]] #score of that team at a given time. 
    team2score = pbp_relevant.loc[pbp_relevant.iloc[:,10] == teams[1]]
    del pbp_relevant['score']

    pbp_relevant = pd.merge(pbp_relevant, team1score.loc[:,['Event_Num','score']], on = 'Event_Num', how = 'left')
    pbp_relevant = pd.merge(pbp_relevant, team2score.loc[:,['Event_Num','score']], on = 'Event_Num', how = 'left')

    # fill forward for NaNs
    pbp_relevant.loc[:,['score_x', 'score_y']] = pbp_relevant.loc[:,['score_x', 'score_y']].fillna(method = 'ffill')
    pbp_relevant.loc[:,['score_x', 'score_y']] = pbp_relevant.loc[:,['score_x', 'score_y']].fillna(0) # for the start of the game
    del team1score, team2score
    
    # Loop through play by play
    for index, row in pbp_relevant.iterrows():
        if (row['Event_Msg_Type'] == 8):
            playersin, bench = sub(playersin, bench, row)  #calculate +/- of subout.
        elif (row['Event_Msg_Type'] == 13):
            playersin, bench = endperiod(playersin, bench, row)  #calculate +/- at end of period,
          #  break

        elif (row['Event_Msg_Type'] == 12):
            playersin, bench = startperiod(playersin, bench, row) #update lineups
        
    pm = pd.concat([bench,playersin])
    pm = pm.sort_values(['Team_id','pm'])
    pm = pm.reset_index(drop=True)

    pm['game_id'] = game
    pms = pms.append(pm)
    print(pm['pm'].sum())


# In[ ]:

pms = pms[['game_id','Person_id','pm']]
pms = pms.rename(index = str, columns = {'game_id': "Game_ID",'Person_id': 'Player_ID','pm': 'Player_Plus/Minus'})


# In[14]:

pms
# Out:
# game id:  006728e4c10e957011e1f24878e6054a
# game num:  0
# 0.0
#                              Game_ID                         Player_ID  \
# 0   006728e4c10e957011e1f24878e6054a  42e0d7167f04a4ff958c6442da0e6851
# 1   006728e4c10e957011e1f24878e6054a  f4a5ca938177c407a9dab5412e39498f
# 2   006728e4c10e957011e1f24878e6054a  c5dd5b2e3b975f0849d9b74e74125cb9
# 3   006728e4c10e957011e1f24878e6054a  2ad626904c8b28cceb8e12c624a84240
# 4   006728e4c10e957011e1f24878e6054a  5db9c1c8184510fee8161e7fafdc9c49
# 5   006728e4c10e957011e1f24878e6054a  766802a8fda500d7945950de7398c9c6
# 6   006728e4c10e957011e1f24878e6054a  618f6d58ab2881152607c2a6e057bc51
# 7   006728e4c10e957011e1f24878e6054a  8d2127290c94bd41b82a2938734bc750
# 8   006728e4c10e957011e1f24878e6054a  ae53f8ba6761b64a174051da817785bc
# 9   006728e4c10e957011e1f24878e6054a  99104de2626f67c1fa2ce70504970c3f
# 10  006728e4c10e957011e1f24878e6054a  616281dee946056b071699476fdee9ec
# 11  006728e4c10e957011e1f24878e6054a  48ec4e6c52f418d5ca4ef510ba473ea0
# 12  006728e4c10e957011e1f24878e6054a  e814950408915f43de2b079dce7c21c5
# 13  006728e4c10e957011e1f24878e6054a  d81d912f81fa43178f423aa89a713e96
# 14  006728e4c10e957011e1f24878e6054a  44230324724c84f122ac62a5f0918314
# 15  006728e4c10e957011e1f24878e6054a  4ef3dae16c436459ff05156abca5cebd
# 16  006728e4c10e957011e1f24878e6054a  5cce6ffa455e6372d9de0de400482ab6
# 17  006728e4c10e957011e1f24878e6054a  4dd3d6a51dc97c651d3a86eec4362a1f
# 18  006728e4c10e957011e1f24878e6054a  4413c19cf092bda39332d7833c90bfe6
#
#    Player_Plus/Minus
# 0                -18
# 1                -18
# 2                -14
# 3                -14
# 4                -14
# 5                  0
# 6                  0
# 7                  3
# 8                  5
# 9                 -5
# 10                -3
# 11                 0
# 12                 0
# 13                 0
# 14                14
# 15                14
# 16                14
# 17                14
# 18                22

# %%
def end_of_possession_flag(z):
    """Creates a 1 or 0 flag to denote whether or not this event code corresponds to the end of a possession.
    
    
    An idea based on this is to then make a running count of this similar to points, get the total # of possessions based on points scored. 
    
    """
    
    
    if z['Event_Msg_Type_Description'] == 'Made Shot':
        return 1 #this is one way to end the possesison, the shot goes in and possesion changes. 
    
    if z[]
# Out:
#   File "<ipython-input-33-f50bc5ee8864>", line 13
#     if z[]
#          ^
# SyntaxError: invalid syntax

# %%
pbp_relevant
# Out:
#                               Game_id  Event_Num  Event_Msg_Type  Period  \
# 0    006728e4c10e957011e1f24878e6054a        4.0            10.0     1.0
# 1    006728e4c10e957011e1f24878e6054a        2.0            12.0     1.0
# 2    006728e4c10e957011e1f24878e6054a        7.0             1.0     1.0
# 159  571240.0   4410.0          3.0      2.0      0.0      0.0   ...
# 160  571460.0   4220.0          4.0      0.0      0.0      0.0   ...
# 161  571700.0   4090.0          1.0      3.0      0.0      0.0   ...
# 162  571730.0   4060.0          0.0      0.0      0.0      0.0   ...
# 163  571770.0   4020.0         79.0      3.0      1.0      0.0   ...
# 164  571800.0   3980.0          0.0      0.0      0.0      0.0   ...
# 165  572010.0   3780.0         79.0      2.0      0.0      0.0   ...
# 166  572250.0   3560.0          1.0      0.0      0.0      0.0   ...
# 167       NaN      NaN          NaN      NaN      NaN      NaN   ...
# 168       NaN      NaN          NaN      NaN      NaN      NaN   ...
# 169  572610.0   3490.0        101.0      2.0      0.0      0.0   ...
# 170  572810.0   3290.0         45.0      0.0      0.0      0.0   ...
# 171  572890.0   3240.0        103.0      2.0      1.0      0.0   ...
# 172  573040.0   3090.0          6.0      2.0      0.0      0.0   ...
# 173  573120.0   3010.0        101.0      2.0      0.0      0.0   ...
# 174  573150.0   2980.0          0.0      0.0      0.0      0.0   ...
# 175  573170.0   2970.0          1.0      0.0      0.0      0.0   ...
# 176       NaN      NaN          NaN      NaN      NaN      NaN   ...
# 177       NaN      NaN          NaN      NaN      NaN      NaN   ...
# 178  573560.0   2770.0          6.0      2.0      0.0      0.0   ...
# 179  573650.0   2690.0          1.0      3.0      0.0      0.0   ...
# 180  573690.0   2650.0          0.0      0.0      0.0      0.0   ...
# 181  573840.0   2500.0          1.0      3.0      0.0      0.0   ...
# 182       NaN      NaN          NaN      NaN      NaN      NaN   ...
# 183  573980.0   2390.0          1.0      0.0      0.0      0.0   ...
# 184  576300.0   2310.0         79.0      2.0      0.0      0.0   ...
# 185  576350.0   2290.0          0.0      0.0      0.0      0.0   ...
# 186  576590.0   2080.0          1.0      2.0      0.0      0.0   ...
# 187  576620.0   2050.0          0.0      0.0      0.0      0.0   ...
# 188  576680.0   1990.0         79.0      2.0      0.0      0.0   ...
# 189  576840.0   1830.0         98.0      2.0      0.0      0.0   ...
# 190  576970.0   1730.0          3.0      0.0      0.0      0.0   ...
# 191  577370.0   1690.0         11.0      1.0      0.0      0.0   ...
# 192  577520.0   1690.0         12.0      1.0      0.0      0.0   ...
# 193  577150.0   1690.0          2.0      0.0      0.0      2.0   ...
# 194  577640.0   1600.0         79.0      3.0      0.0      0.0   ...
# ...
# 159                          Hook Shot    89.0    78.0
# 160                          Traveling    89.0    78.0
# 161                          Jump Shot    92.0    78.0
# 162                            Unknown    92.0    78.0
# 163                   Pullup Jump shot    92.0    81.0
# 164                            Unknown    92.0    81.0
# 165                   Pullup Jump shot    94.0    81.0
# 166                           Personal    94.0    81.0
# 167                                NaN    94.0    81.0
# 168                                NaN    94.0    81.0
# 169         Driving Floating Jump Shot    94.0    83.0
# 170  Out of Bounds - Bad Pass Turnover    94.0    83.0
# 171          Running Pull-Up Jump Shot    94.0    85.0
# 172                 Driving Layup Shot    96.0    85.0
# 173         Driving Floating Jump Shot    96.0    87.0
# 174                            Unknown    96.0    87.0
# 175                           Personal    96.0    87.0
# 176                                NaN    96.0    87.0
# 177                                NaN    96.0    87.0
# 178                 Driving Layup Shot    98.0    87.0
# 179                          Jump Shot    98.0    90.0
# 180                            Unknown    98.0    90.0
# 181                          Jump Shot   101.0    90.0
# 182                                NaN   101.0    90.0
# 183                            Regular   101.0    90.0
# 184                   Pullup Jump shot   101.0    92.0
# 185                            Unknown   101.0    92.0
# 186                          Jump Shot   103.0    92.0
# 187                            Unknown   103.0    92.0
# 188                   Pullup Jump shot   105.0    92.0
# 189                 Cutting Layup Shot   105.0    94.0
# 190                      Out-of-Bounds   105.0    94.0
# 191                  Free Throw 1 of 2   106.0    94.0
# 192                  Free Throw 2 of 2   107.0    94.0
# 193                           Shooting   107.0    94.0
# 194                   Pullup Jump shot   107.0    97.0
# 195                 Driving Layup Shot   109.0    97.0
# 196                Step Back Jump shot   109.0   100.0
# 197                 Fadeaway Jump Shot   111.0   100.0
# 198                         Layup Shot   111.0   102.0
# 199                            Unknown   111.0   102.0
# 200                 Cutting Layup Shot   113.0   102.0
# 201                            Unknown   113.0   102.0
# 202                 Driving Layup Shot   113.0   104.0
# 203  Out of Bounds - Bad Pass Turnover   113.0   104.0
# 204                                NaN   113.0   104.0
# 205                          Jump Shot   113.0   107.0
# 206                          Jump Shot   116.0   107.0
# 207                            Unknown   116.0   107.0
# 208                           Personal   116.0   107.0
# 209                   Pullup Jump shot   116.0   110.0
# 210                            Unknown   116.0   110.0
# 211                      Out-of-Bounds   116.0   110.0
# 212                 Fadeaway Jump Shot   118.0   110.0
# 213                            Unknown   118.0   110.0
# 214                          Jump Shot   120.0   110.0
# 215                            Unknown   120.0   110.0
# 216                                      120.0   110.0
# 217                                      120.0   110.0
# 218                 Floating Jump shot   120.0   112.0
# 219                  Free Throw 1 of 2   121.0   112.0
# 220                  Free Throw 2 of 2   122.0   112.0
# 221                           Shooting   122.0   112.0
# 222                  Cutting Dunk Shot   122.0   114.0
# 223                          Jump Shot   125.0   114.0
# 224                          Hook Shot   125.0   116.0
# 225                            Unknown   125.0   116.0
# 226  Out of Bounds - Bad Pass Turnover   125.0   116.0
# 227        Step Out of Bounds Turnover   125.0   116.0
# 228                           Personal   125.0   116.0
# 229                 Cutting Layup Shot   127.0   116.0
# 230                            Unknown   127.0   116.0
# 231                  Free Throw 1 of 2   127.0   117.0
# 232                  Free Throw 2 of 2   127.0   118.0
# 233                           Shooting   127.0   118.0
# 234                   Pullup Jump shot   129.0   118.0
# 235                  Free Throw 1 of 2   129.0   119.0
# 236                  Free Throw 2 of 2   129.0   120.0
# 237                     Shooting Block   129.0   120.0
# 238                 Driving Layup Shot   131.0   120.0
# 239                          Jump Shot   131.0   123.0
# 240                            Unknown   131.0   123.0
# 241                 Driving Layup Shot   133.0   123.0
# 242                            Unknown   133.0   123.0
# 243                  Free Throw 1 of 2   133.0   124.0
# 244                  Free Throw 2 of 2   133.0   124.0
# 245                           Shooting   133.0   124.0
# 246                            Unknown   133.0   124.0
# 247    Driving Floating Bank Jump Shot   133.0   126.0
# 248                          Jump Shot   136.0   126.0
# 249                            Unknown   136.0   126.0
# 250                   Pullup Jump shot   139.0   126.0
# 251                            Unknown   139.0   126.0
# 252                      Personal Take   139.0   126.0
# 253                          Jump Shot   139.0   129.0
# 254                            Unknown   139.0   129.0
# 255                   Pullup Jump shot   141.0   129.0
# 256                            Regular   141.0   129.0
# 257                      Out-of-Bounds   141.0   129.0
# 258                  Free Throw 1 of 2   141.0   130.0
# 259                  Free Throw 2 of 2   141.0   131.0
# 260                           Shooting   141.0   132.0
# 261                                NaN   141.0   132.0
# 262            Offensive Foul Turnover   141.0   132.0
# 263                          Offensive   142.0   132.0
# 264                Alley Oop Dunk Shot   142.0   134.0
# 265                 Fadeaway Jump Shot   144.0   134.0
# 266                            Unknown   144.0   134.0
# 267                 Reverse Layup Shot   144.0   136.0
# 268                            Unknown   144.0   136.0
# 269                Shot Clock Turnover   144.0   136.0
# 270                   Pullup Jump shot   146.0   136.0
# 271                          Jump Shot   146.0   138.0
# 272                           Bad Pass   147.0   138.0
# 273         Driving Floating Jump Shot   147.0   140.0
# 274                            Unknown   147.0   140.0
# 275         Driving Floating Jump Shot   149.0   140.0
# 276                            Unknown   149.0   140.0
# 277            Offensive Foul Turnover   149.0   140.0
# 278                          Offensive   149.0   140.0
# 279                                NaN   149.0   140.0
# 280                                NaN   149.0   140.0
# 281                           Bad Pass   150.0   140.0
# 282                 Running Layup Shot   150.0   142.0
# 283                            Unknown   150.0   142.0
# 284          Running Pull-Up Jump Shot   153.0   142.0
# 285                         Layup Shot   153.0   144.0
# 286                            Unknown   153.0   144.0
# 287                     Tip Layup Shot   153.0   146.0
# 288                            Unknown   153.0   146.0
# 289                     Tip Layup Shot   153.0   148.0
# 290                            Unknown   153.0   148.0
# 291                                NaN   153.0   148.0
# 292                                NaN   153.0   148.0
# 293                                NaN   153.0   148.0
# 294                            Regular   153.0   148.0
# 295                      Out-of-Bounds   153.0   148.0
# 296                          Jump Shot   156.0   148.0
# 297                            Unknown   156.0   148.0
# 298                          Jump Shot   156.0   151.0
# 299                            Unknown   156.0   151.0
# 300  Out of Bounds - Bad Pass Turnover   156.0   151.0
# 301                   Pullup Jump shot   156.0   153.0
# 302                            Unknown   156.0   153.0
# 303                  Free Throw 1 of 2   157.0   153.0
# 304                  Free Throw 2 of 2   158.0   153.0
# 305                           Shooting   158.0   153.0
# 306                                NaN   158.0   153.0
# 307    Driving Floating Bank Jump Shot   158.0   155.0
# 308                           Personal   158.0   155.0
# 309                  Free Throw 1 of 2   159.0   155.0
# 310                  Free Throw 2 of 2   159.0   155.0
# 311                           Shooting   160.0   155.0
# 312                            Unknown   160.0   155.0
# 313                Step Back Jump shot   160.0   157.0
# 314                 Putback Layup Shot   160.0   159.0
# 315                            Unknown   160.0   159.0
# 316                  Free Throw 1 of 2   161.0   159.0
# 317                  Free Throw 2 of 2   162.0   159.0
# 318                           Shooting   163.0   159.0
# 319                   Pullup Jump shot   163.0   162.0
# 320                            Unknown   163.0   162.0
# 321               Turnaround Jump Shot   165.0   162.0
# 322               Turnaround Jump Shot   165.0   164.0
# 323         Driving Floating Jump Shot   167.0   164.0
# 324                     Tip Layup Shot   169.0   164.0
# 325                            Unknown   169.0   164.0
# 326                                      169.0   164.0
# 327                                      169.0   164.0
# 328                 Driving Layup Shot   171.0   164.0
# 329                            Unknown   171.0   164.0
# 330                  Free Throw 1 of 2   171.0   165.0
# 331                  Free Throw 2 of 2   171.0   166.0
# 332                           Shooting   171.0   166.0
# 333                                NaN   171.0   166.0
# 334                 Fadeaway Jump Shot   173.0   166.0
# 335                            Unknown   173.0   166.0
# 336                                NaN   173.0   166.0
# 337                      Out-of-Bounds   173.0   166.0
# 338                   Pullup Jump shot   173.0   169.0
# 339                            Unknown   173.0   169.0
# 340                   Pullup Jump shot   175.0   169.0
# 341                            Unknown   175.0   169.0
# 342                          Jump Shot   175.0   172.0
# 343                  Free Throw 1 of 2   176.0   172.0
# 344                  Free Throw 2 of 2   177.0   172.0
# 345                           Shooting   177.0   172.0
# 346                                NaN   177.0   172.0
# 347                      Court Cleanup   177.0   172.0
# 348                      Out-of-Bounds   177.0   172.0
# 349               Turnaround Hook Shot   177.0   174.0
# 350                 Driving Layup Shot   179.0   174.0
# 351                            Unknown   179.0   174.0
# 352                           Personal   179.0   174.0
# 353         Driving Floating Jump Shot   179.0   176.0
# 354                            Unknown   179.0   176.0
# 355                     Tip Layup Shot   179.0   178.0
# 356                  Free Throw 1 of 2   179.0   178.0
# 357                  Free Throw 2 of 2   179.0   179.0
# 358                            Unknown   179.0   179.0
# 359                     Normal Rebound   179.0   179.0
# 360                           Shooting   179.0   179.0
# 361                           Bad Pass   180.0   179.0
# 362                          Jump Shot   180.0   182.0
# 363                                NaN   180.0   182.0
# 364                            Regular   180.0   182.0
# 365                 Driving Layup Shot   182.0   182.0
# 366                            Unknown   182.0   182.0
# 367                          Jump Shot   185.0   182.0
# 368                          Lost Ball   185.0   183.0
# 369                           Bad Pass   186.0   183.0
# 370                          Jump Shot   186.0   186.0
# 371                            Unknown   186.0   186.0
# 372                 Driving Layup Shot   186.0   188.0
# 373                 Driving Layup Shot   188.0   188.0
# 374                            Unknown   188.0   188.0
# 375                           Personal   188.0   188.0
# 376                 Cutting Layup Shot   188.0   190.0
# 377                            Unknown   188.0   190.0
# 378                  Putback Dunk Shot   188.0   192.0
# 379                   Pullup Jump shot   190.0   192.0
# 380                            Unknown   190.0   192.0
# 381                  Free Throw 1 of 2   191.0   192.0
# 382                  Free Throw 2 of 2   192.0   192.0
# 383                           Shooting   192.0   192.0
# 384                                NaN   192.0   192.0
# 385                                NaN   192.0   192.0
# 386                                NaN   192.0   192.0
# 387                            Regular   192.0   192.0
# 388                 Cutting Layup Shot   192.0   194.0
# 389                   Pullup Jump shot   195.0   194.0
# 390                            Unknown   195.0   194.0
# 391         Driving Floating Jump Shot   195.0   196.0
# 392                          Jump Shot   197.0   196.0
# 393                            Unknown   197.0   196.0
# 394                          Jump Shot   197.0   199.0
# 395                            Unknown   197.0   199.0
# 396                          Jump Shot   197.0   201.0
# 397                            Unknown   197.0   201.0
# 398                          Jump Shot   200.0   201.0
# 399                 Driving Layup Shot   200.0   203.0
# 400                           Bad Pass   201.0   203.0
# 401                 Cutting Layup Shot   201.0   205.0
# 402                  Free Throw 1 of 1   201.0   205.0
# 403                            Unknown   201.0   205.0
# 404                           Shooting   201.0   206.0
# 405                                NaN   201.0   206.0
# 406                            Regular   201.0   206.0
# 407               Alley Oop Layup shot   203.0   206.0
# 408                                NaN   203.0   206.0
# 409                            Regular   203.0   206.0
# 410                  Free Throw 1 of 2   203.0   207.0
# 411                  Free Throw 2 of 2   203.0   208.0
# 412                           Personal   203.0   209.0
# 413                          Jump Shot   206.0   209.0
# 414                            Unknown   206.0   209.0
# 415                   Pullup Jump shot   206.0   212.0
# 416                            Unknown   206.0   212.0
# 417                           Personal   206.0   212.0
# 418                           Bad Pass   207.0   212.0
# 419               Alley Oop Layup shot   207.0   214.0
# 420                            Unknown   207.0   214.0
# 421                 Driving Layup Shot   207.0   216.0
# 422                         Layup Shot   209.0   216.0
# 423                            Unknown   209.0   216.0
# 424                            Regular   209.0   216.0
# 425                   Pullup Jump shot   209.0   219.0
# 426                            Unknown   209.0   219.0
# 427                          Jump Shot   209.0   222.0
# 428                            Unknown   209.0   222.0
# 429                  Free Throw 1 of 2   209.0   223.0
# 430                  Free Throw 2 of 2   209.0   224.0
# 431                           Shooting   209.0   225.0
# 432               Turnaround Jump Shot   211.0   225.0
# 433         Driving Floating Jump Shot   211.0   227.0
# 434                            Unknown   211.0   227.0
# 435                 Driving Layup Shot   213.0   227.0
# 436                            Unknown   213.0   227.0
# 437                                      213.0   227.0
# 438                                      213.0   227.0
#
# [439 rows x 22 columns]

# %%
ec
# Out:
#      Event_Msg_Type  Action_Type                Event_Msg_Type_Description  \
# 0                 1            0  Made Shot
# 1                 1            1  Made Shot
# 2                 1            2  Made Shot
# 3                 1            3  Made Shot
# 4                 1            4  Made Shot
# 5                 1            5  Made Shot
# 6                 1            6  Made Shot
# 7                 1            7  Made Shot
# 8                 1            8  Made Shot
# 9                 1            9  Made Shot
# 10                1           40  Made Shot
# 11                1           41  Made Shot
# 12                1           42  Made Shot
# 13                1           43  Made Shot
# 14                1           44  Made Shot
# 15                1           45  Made Shot
# 16                1           46  Made Shot
# 17                1           47  Made Shot
# 18                1           48  Made Shot
# 19                1           49  Made Shot
# 20                1           50  Made Shot
# 21                1           51  Made Shot
# 22                1           52  Made Shot
# 23                1           53  Made Shot
# 24                1           54  Made Shot
# 25                1           55  Made Shot
# 26                1           56  Made Shot
# 27                1           57  Made Shot
# 28                1           58  Made Shot
# 29                1           59  Made Shot
# 30                1           60  Made Shot
# 31                1           61  Made Shot
# 32                1           62  Made Shot
# 33                1           63  Made Shot
# 34                1           64  Made Shot
# 35                1           65  Made Shot
# 36                1           66  Made Shot
# 37                1           67  Made Shot
# 38                1           71  Made Shot
# 39                1           72  Made Shot
# 40                1           73  Made Shot
# 41                1           74  Made Shot
# 42                1           75  Made Shot
# 43                1           76  Made Shot
# 44                1           77  Made Shot
# 45                1           78  Made Shot
# 46                1           79  Made Shot
# 47                1           80  Made Shot
# 48                1           81  Made Shot
# 49                1           82  Made Shot
# 50                1           83  Made Shot
# 51                1           84  Made Shot
# 52                1           85  Made Shot
# 53                1           86  Made Shot
# 54                1           87  Made Shot
# 55                1           88  Made Shot
# 56                1           89  Made Shot
# 57                1           90  Made Shot
# 58                1           91  Made Shot
# 59                1           92  Made Shot
# 60                1           93  Made Shot
# 61                1           94  Made Shot
# 62                1           95  Made Shot
# 63                1           96  Made Shot
# 64                1           97  Made Shot
# 65                1           98  Made Shot
# 66                1           99  Made Shot
# 67                1          100  Made Shot
# 68                1          101  Made Shot
# 69                1          102  Made Shot
# 70                1          103  Made Shot
# 71                1          104  Made Shot
# 72                1          105  Made Shot
# 73                1          106  Made Shot
# 74                1          107  Made Shot
# 75                1          108  Made Shot
# 76                1          109  Made Shot
# 77                1          110  Made Shot
# 78                2            0  Missed Shot
# 79                2            1  Missed Shot
# 80                2            2  Missed Shot
# 81                2            3  Missed Shot
# 82                2            4  Missed Shot
# 83                2            5  Missed Shot
# 84                2            6  Missed Shot
# 85                2            7  Missed Shot
# 86                2            8  Missed Shot
# 87                2            9  Missed Shot
# 88                2           40  Missed Shot
# 89                2           41  Missed Shot
# 90                2           42  Missed Shot
# 91                2           43  Missed Shot
# 92                2           44  Missed Shot
# 93                2           45  Missed Shot
# 94                2           46  Missed Shot
# 95                2           47  Missed Shot
# 96                2           48  Missed Shot
# 97                2           49  Missed Shot
# 98                2           50  Missed Shot
# 99                2           51  Missed Shot
# 100               2           52  Missed Shot
# 101               2           53  Missed Shot
# 102               2           54  Missed Shot
# 103               2           55  Missed Shot
# 104               2           56  Missed Shot
# 105               2           57  Missed Shot
# 106               2           58  Missed Shot
# 107               2           59  Missed Shot
# 108               2           60  Missed Shot
# 109               2           61  Missed Shot
# 110               2           62  Missed Shot
# 111               2           63  Missed Shot
# 112               2           64  Missed Shot
# 113               2           65  Missed Shot
# 114               2           66  Missed Shot
# 115               2           67  Missed Shot
# 116               2           71  Missed Shot
# 117               2           72  Missed Shot
# 118               2           73  Missed Shot
# 119               2           74  Missed Shot
# 120               2           75  Missed Shot
# 121               2           76  Missed Shot
# 122               2           77  Missed Shot
# 123               2           78  Missed Shot
# 124               2           79  Missed Shot
# 125               2           80  Missed Shot
# 126               2           81  Missed Shot
# 127               2           82  Missed Shot
# 128               2           83  Missed Shot
# 129               2           84  Missed Shot
# 130               2           85  Missed Shot
# 131               2           86  Missed Shot
# 132               2           87  Missed Shot
# 133               2           88  Missed Shot
# 134               2           89  Missed Shot
# 135               2           90  Missed Shot
# 136               2           91  Missed Shot
# 137               2           92  Missed Shot
# 138               2           93  Missed Shot
# 139               2           94  Missed Shot
# 140               2           95  Missed Shot
# 141               2           96  Missed Shot
# 142               2           97  Missed Shot
# 143               2           98  Missed Shot
# 144               2           99  Missed Shot
# 145               2          100  Missed Shot
# 146               2          101  Missed Shot
# 147               2          102  Missed Shot
# 148               2          103  Missed Shot
# 149               2          104  Missed Shot
# 150               2          105  Missed Shot
# 151               2          106  Missed Shot
# 152               2          107  Missed Shot
# 272              12            0  Start Period
# 273              13            0  End Period
# 274              14            0  Validation
# 275              15            0  Memo
# 276              15            1  Memo
# 277              15            2  Memo
# 278              15            3  Memo
# 279              15            4  Flash Stats
# 280              15            5  Memo
# 281              15            6  Memo
# 282              15            7  Memo
# 283              15            8  Supplemental
# 284              15            9  Memo
# 285              15           16  Ejection
# 286              15           26  Memo
# 287              15           32  Instant Replay
# 288              16            0  Final Box Printed
# 289              18            0  Instant Replay
# 290              18            1  Instant Replay
# 291              18            2  Instant Replay
# 292              20            0  Stoppage
# 293              20            1  Stoppage
# 294              20            2  Stoppage
# 295              20            3  Stoppage
# 296              20            4  Stoppage
# 297              20            5  Stoppage
# 298              20            6  Stoppage
#
#                       Action_Type_Description
# 0                                     No Shot
# 1                                   Jump Shot
# 2                           Running Jump Shot
# 3                                   Hook Shot
# 4                                    Tip Shot
# 5                                  Layup Shot
# 6                          Driving Layup Shot
# 7                                   Dunk Shot
# 8                              Slam Dunk Shot
# 9                           Driving Dunk Shot
# 10                                 Layup Shot
# 11                         Running Layup Shot
# 12                         Driving Layup Shot
# 13                       Alley Oop Layup shot
# 14                         Reverse Layup Shot
# 15                                  Jump Shot
# 16                          Running Jump Shot
# 17                       Turnaround Jump Shot
# 18                                  Dunk Shot
# 19                          Driving Dunk Shot
# 20                          Running Dunk Shot
# 21                          Reverse Dunk Shot
# 22                        Alley Oop Dunk Shot
# 23                                   Tip Shot
# 24                           Running Tip Shot
# 25                                  Hook Shot
# 26                          Running Hook Shot
# 27                          Driving Hook Shot
# 28                       Turnaround Hook Shot
# 29                           Finger Roll Shot
# 30                   Running Finger Roll Shot
# 31                   Driving Finger Roll Shot
# 32                Turnaround Finger Roll Shot
# 33                         Fadeaway Jump Shot
# 34                        Follow Up Dunk Shot
# 35                             Jump Hook Shot
# 36                             Jump Bank Shot
# 37                             Hook Bank Shot
# 38                     Finger Roll Layup Shot
# 39                         Putback Layup Shot
# 40                 Driving Reverse Layup Shot
# 41                 Running Reverse Layup Shot
# 42             Driving Finger Roll Layup Shot
# 43             Running Finger Roll Layup Shot
# 44                          Driving Jump shot
# 45                         Floating Jump shot
# 46                           Pullup Jump shot
# 47                        Step Back Jump shot
# 48                           Pullup Bank shot
# 49                          Driving Bank shot
# 50                         Fadeaway Bank shot
# 51                          Running Bank shot
# 52                       Turnaround Bank shot
# 53                   Turnaround Fadeaway shot
# 54                          Putback Dunk Shot
# 55                     Driving Slam Dunk Shot
# 56                     Reverse Slam Dunk Shot
# 57                     Running Slam Dunk Shot
# 58                  Putback Reverse Dunk Shot
# 59                     Putback Slam Dunk Shot
# 60                     Driving Bank Hook Shot
# 61                        Jump Bank Hook Shot
# 62                     Running Bank Hook Shot
# 63                  Turnaround Bank Hook Shot
# 64                             Tip Layup Shot
# 65                         Cutting Layup Shot
# 66             Cutting Finger Roll Layup Shot
# 67               Running Alley Oop Layup Shot
# 68                 Driving Floating Jump Shot
# 69            Driving Floating Bank Jump Shot
# 70                  Running Pull-Up Jump Shot
# 71                   Step Back Bank Jump Shot
# 72         Turnaround Fadeaway Bank Jump Shot
# 73                Running Alley Oop Dunk Shot
# 74                              Tip Dunk Shot
# 75                          Cutting Dunk Shot
# 76                  Driving Reverse Dunk Shot
# 77                  Running Reverse Dunk Shot
# 78                                    No Shot
# 79                                  Jump Shot
# 80                          Running Jump Shot
# 81                                  Hook Shot
# 82                                   Tip Shot
# 83                                 Layup Shot
# 84                         Driving Layup Shot
# 85                                  Dunk Shot
# 86                             Slam Dunk Shot
# 87                          Driving Dunk Shot
# 88                                 Layup Shot
# 89                         Running Layup Shot
# 90                         Driving Layup Shot
# 91                       Alley Oop Layup shot
# 92                         Reverse Layup Shot
# 93                                  Jump Shot
# 94                          Running Jump Shot
# 95                       Turnaround Jump Shot
# 96                                  Dunk Shot
# 97                          Driving Dunk Shot
# 98                          Running Dunk Shot
# 99                          Reverse Dunk Shot
# 100                       Alley Oop Dunk Shot
# 101                                  Tip Shot
# 102                          Running Tip Shot
# 103                                 Hook Shot
# 104                         Running Hook Shot
# 105                         Driving Hook Shot
# 106                      Turnaround Hook Shot
# 107                          Finger Roll Shot
# 108                  Running Finger Roll Shot
# 109                  Driving Finger Roll Shot
# 110               Turnaround Finger Roll Shot
# 111                        Fadeaway Jump Shot
# 112                       Follow Up Dunk Shot
# 113                            Jump Hook Shot
# 114                            Jump Bank Shot
# 115                            Hook Bank Shot
# 116                    Finger Roll Layup Shot
# 117                        Putback Layup Shot
# 118                Driving Reverse Layup Shot
# 119                Running Reverse Layup Shot
# 120            Driving Finger Roll Layup Shot
# 121            Running Finger Roll Layup Shot
# 122                         Driving Jump shot
# 123                        Floating Jump shot
# 124                          Pullup Jump shot
# 125                       Step Back Jump shot
# 126                          Pullup Bank shot
# 127                         Driving Bank shot
# 128                        Fadeaway Bank shot
# 129                         Running Bank shot
# 130                      Turnaround Bank shot
# 131                  Turnaround Fadeaway shot
# 132                         Putback Dunk Shot
# 133                    Driving Slam Dunk Shot
# 134                    Reverse Slam Dunk Shot
# 135                    Running Slam Dunk Shot
# 136                 Putback Reverse Dunk Shot
# 137                    Putback Slam Dunk Shot
# 138                    Driving Bank Hook Shot
# 139                       Jump Bank Hook Shot
# 140                    Running Bank Hook Shot
# 141                 Turnaround Bank Hook Shot
# 142                            Tip Layup Shot
# 143                        Cutting Layup Shot
# 144            Cutting Finger Roll Layup Shot
# 145              Running Alley Oop Layup Shot
# 146                Driving Floating Jump Shot
# 147           Driving Floating Bank Jump Shot
# 148                 Running Pull-Up Jump Shot
# 149                  Step Back Bank Jump Shot
# 150        Turnaround Fadeaway Bank Jump Shot
# 151               Running Alley Oop Dunk Shot
# 152                             Tip Dunk Shot
# 153                         Cutting Dunk Shot
# 154                 Driving Reverse Dunk Shot
# 155                 Running Reverse Dunk Shot
# 156                                       NaN
# 157                         Free Throw 1 of 1
# 158                         Free Throw 1 of 2
# 159                         Free Throw 2 of 2
# 160                         Free Throw 1 of 3
# 161                         Free Throw 2 of 3
# 162                         Free Throw 3 of 3
# 163                      Free Throw Technical
# 164                     Free Throw Clear Path
# 165                Free Throw Flagrant 1 of 2
# 166                Free Throw Flagrant 2 of 2
# 167                Free Throw Flagrant 1 of 1
# 168               Free Throw Technical 1 of 2
# 169               Free Throw Technical 2 of 2
# 170              Free Throw Clear Path 1 of 2
# 171              Free Throw Clear Path 2 of 2
# 172                Free Throw Flagrant 1 of 3
# 173                Free Throw Flagrant 2 of 3
# 174                Free Throw Flagrant 3 of 3
# 175                                   Unknown
# 176                            Normal Rebound
# 177                         Dead Ball Rebound
# 178                               No Turnover
# 179                                  Bad Pass
# 180                                 Lost Ball
# 181                             Out Of Bounds
# 182                                 Traveling
# 183                                      Foul
# 184                            Double Dribble
# 185                       Discontinue Dribble
# 186                        3 Second Violation
# 187                        5 Second Violation
# 188                        8 Second Violation
# 189                       Shot Clock Turnover
# 190                          Inbound Turnover
# 191                        Backcourt Turnover
# 192                              Illegal Pick
# 193                     Offensive Goaltending
# 194                       Isolation Violation
# 195                            Lane Violation
# 196                       Jump Ball Violation
# 197                     Kicked Ball Violation
# 198                   Illegal Assist Turnover
# 199                          Palming Turnover
# 200                          Post Up Turnover
# 201                  Double Personal Turnover
# 202                        10 Second Violaton
# 203                      Stolen Pass Turnover
# 204                  Opposite Basket Turnover
# 205                     Punched Ball Turnover
# 206                  Swinging Elbows Turnover
# 207                Basket from Below Turnover
# 208                   Illegal Screen Turnover
# 209                   Offensive Foul Turnover
# 210                 5 Second Inbound Turnover
# 211               Step Out of Bounds Turnover
# 212          Out of Bounds Lost Ball Turnover
# 213                   Poss Lost Ball Turnover
# 214                   Excess Timeout Turnover
# 215   Player Out of Bounds Violation Turnover
# 216                 Too Many Players Turnover
# 217         Out of Bounds - Bad Pass Turnover
# 218                                   No Foul
# 219                                  Personal
# 220                                  Shooting
# 221                                Loose Ball
# 222                                 Offensive
# 223                                   Inbound
# 224                            Away From Play
# 225                                     Elbow
# 226                                  Punching
# 227                                Clear Path
# 228                           Double Personal
# 229                                 Technical
# 230             Non-Unsportsmanlike Technical
# 231                         Hanging Technical
# 232                           Flagrant Type 1
# 233                           Flagrant Type 2
# 234                          Double Technical
# 235                          Defense 3 Second
# 236                           Delay Technical
# 237                        Taunting Technical
# 238                            Player Control
# 239                        Indirect Technical
# 240                  Excess Timeout Technical
# 241                          Offensive Charge
# 242                            Personal Block
# 243                             Personal Take
# 244                            Shooting Block
# 245                Too Many Players Technical
# 246                              No Violation
# 247                             Delay Of Game
# 248                     Defensive Goaltending
# 249                                      Lane
# 250                                 Jump Ball
# 251                               Kicked Ball
# 252                               Double Lane
# 253                           Illegal Defense
# 254
# 255
# 256
# 257
# 258
# 259                                No Timeout
# 260                                   Regular
# 261                                     Short
# 262                               Official TV
# 263                                  Official
# 264                                   Advance
# 265                                     Reset
# 266
# 267                               No Ejection
# 268                          Second Technical
# 269                    Second Flagrant Type 1
# 270                     First Flagrant Type 2
# 271                                     Other
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279                                       NaN
# 280
# 281
# 282
# 283                                       NaN
# 284
# 285                                       NaN
# 286
# 287                                       NaN
# 288
# 289                            Support Ruling
# 290                           Overturn Ruling
# 291                        Altercation Ruling
# 292                               No Stoppage
# 293                                Blood Rule
# 294                                    Injury
# 295                             Out-of-Bounds
# 296                             Court Cleanup
# 297                     Equipment Malfunction
# 298  Other

# %% [markdown]
# What is a possession?  Any time there is a made shot.
#
# Made free throw x of x.
#
# Defensive rebound
#
# turnover
#
# end of period.

# %%
# sort out play by play for singe game
    pbp1 = pbp.loc[pbp['Game_id'] == sample_games[game_num]]
#Properly sorted format.
   # pbp1 = pbp1.sort_values(['Period','PC_Time','WC_Time','Event_Num'],
   #     ascending=[True,False,True,True])

#New theory for sorting...
    pbp1 = pbp1.sort_values(['Period','PC_Time','Event_Msg_Type','WC_Time','Event_Num'],
        ascending=[True,False,True,True,True])
#Here would be a good place to add FTE
#     pbp1 = pbp1.reset_index(drop=True)

#translate to understand what each play is.
    pbp1 = pd.merge(pbp1, codes,
        on = ['Event_Msg_Type', 'Action_Type'], how = 'left')

# subset out extraneous plays, only need scoring plays, free throws, subsitions
# start and end of period
    pbpx = pbp1.loc[(pbp1['Event_Msg_Type'] == 1) |
        (pbp1['Event_Msg_Type'] == 3) | (pbp1['Event_Msg_Type'] == 8) |
        (pbp1['Event_Msg_Type'] == 12) | (pbp1['Event_Msg_Type'] == 13)]
    del pbpx['Action_Type_Description']
    lineup1 = lineup.loc[(lineup['Game_id'] == game)]
    subsmask = pbpx['Event_Msg_Type'] == 8
    subs = pbpx[subsmask]
    playersin = pd.DataFrame(lineup1.loc[(lineup1['Period'] == 1),['Team_id','Person_id']])
    subs_correct = substitution_correction(subs,lineup1)
  #  print( subs_correct.isna().sum())
    pbpx[subsmask] =  subs_correct.values


    playersin['diffin'] = playersin['pm'] = 0
    bench = pd.DataFrame(columns = ['Team_id', 'Person_id', 'diffin', 'pm'])
    #### Cleaning now complete, now calculating pm for every game.

    pbpx.loc[(pbpx['Event_Msg_Type'] == 3)&(pbpx['Option1'] != 1), 'Option1'] = 0
    pbpx['score'] = pbpx.groupby('Team_id', axis = 0)['Option1'].cumsum()
    team1score = pbpx.loc[pbpx.iloc[:,10] == teams[0]]
    team2score = pbpx.loc[pbpx.iloc[:,10] == teams[1]]
    del pbpx['score']

    pbpx = pd.merge(pbpx, team1score.loc[:,['Event_Num','score']], on = 'Event_Num', how = 'left')
    pbpx = pd.merge(pbpx, team2score.loc[:,['Event_Num','score']], on = 'Event_Num', how = 'left')

    # fill forward for NaNs
    pbpx.loc[:,['score_x', 'score_y']] = pbpx.loc[:,['score_x', 'score_y']].fillna(method = 'ffill')
    pbpx.loc[:,['score_x', 'score_y']] = pbpx.loc[:,['score_x', 'score_y']].fillna(0) # for the start of the game
    del team1score, team2score

    # Loop through play by play
    for index, row in pbpx.iterrows():
        if (row['Event_Msg_Type'] == 8):
            playersin, bench = sub(playersin, bench, row)  #calculate +/- of subout.
        elif (row['Event_Msg_Type'] == 13):
            playersin, bench = endperiod(playersin, bench, row)  #calculate +/- at end of period,
        elif (row['Event_Msg_Type'] == 12):
            playersin, bench = startperiod(playersin, bench, row) #update lineups

    pm = pd.concat([bench,playersin])
    pm = pm.sort_values(['Team_id','pm'])
    pm = pm.reset_index(drop=True)

    pm['game_id'] = game
    pms = pms.append(pm)
    print(pm['pm'].sum())


# In[ ]:

pms = pms[['game_id','Person_id','pm']]
pms = pms.rename(index = str, columns = {'game_id': "Game_ID",'Person_id': 'Player_ID','pm': 'Player_Plus/Minus'})


# In[14]:

pms


# In[15]:
# Out:
# game id:  006728e4c10e957011e1f24878e6054a
# game num:  0
# /Users/noahkasmanoff/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/noahkasmanoff/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/noahkasmanoff/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-2a640ff37a4e> in <module>()
#      42     subs_correct = substitution_correction(subs,lineup1)
#      43   #  print( subs_correct.isna().sum())
# ---> 44     pbpx[subsmask] =  subs_correct.values
#      45
#      46
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3114             self._setitem_frame(key, value)
#    3115         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3116             self._setitem_array(key, value)
#    3117         else:
#    3118             # set column
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3132             indexer = key.nonzero()[0]
#    3133             self._check_setitem_copy()
# -> 3134             self.loc._setitem_with_indexer(indexer, value)
#    3135         else:
#    3136             if isinstance(value, DataFrame):
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     588                     value = np.array(value, dtype=object)
#     589                     if len(labels) != value.shape[1]:
# --> 590                         raise ValueError('Must have equal len keys and value '
#     591                                          'when setting with an ndarray')
#     592
#
# ValueError: Must have equal len keys and value when setting with an ndarray

# %%
subsmask
# Out:
# 1      False
# 2      False
# 3      False
# 5      False
# 10     False
# 11     False
# 14     False
# 20     False
# 23     False
# 25     False
# 35     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 59     False
# 62      True
# 63      True
# 65     False
# 70     False
# 71      True
# 72      True
# 73      True
# 86      True
# 87      True
# 88     False
# 89     False
# 96      True
# 97     False
# 98     False
# 99     False
# 101     True
# 106    False
# 107    False
# 108    False
# 116    False
# 117    False
# 118    False
# 119    False
# 121    False
# 125    False
# 138    False
# 139     True
# 141    False
# 142    False
# 145    False
# 147     True
# 148     True
# 149     True
# 151    False
# 152    False
# 159    False
# 165    False
# 167     True
# 168     True
# 169    False
# 171    False
# 172    False
# 176     True
# 177     True
# 178    False
# 181    False
# 182     True
# 188    False
# 189    False
# 191    False
# 192    False
# 194    False
# 195    False
# 196    False
# 197    False
# 202    False
# 204     True
# 205    False
# 216    False
# 217    False
# 218    False
# 219    False
# 220    False
# 222    False
# 223    False
# 231    False
# 232    False
# 234    False
# 235    False
# 236    False
# 238    False
# 243    False
# 244    False
# 247    False
# 255    False
# 258    False
# 259    False
# 261     True
# 264    False
# 270    False
# 271    False
# 279     True
# 280     True
# 284    False
# 291     True
# 292     True
# 293     True
# 303    False
# 304    False
# 306     True
# 307    False
# 309    False
# 310    False
# 314    False
# 316    False
# 317    False
# 321    False
# 322    False
# 324    False
# 326    False
# 327    False
# 330    False
# 331    False
# 333     True
# 336     True
# 342    False
# 343    False
# 344    False
# 346     True
# 349    False
# 356    False
# 357    False
# 362    False
# 363     True
# 367    False
# 372    False
# 378    False
# 381    False
# 382    False
# 384     True
# 385     True
# 386     True
# 388    False
# 391    False
# 398    False
# 399    False
# 401    False
# 402    False
# 405     True
# 407    False
# 408     True
# 410    False
# 411    False
# 421    False
# 429    False
# 430    False
# 432    False
# 437    False
# Name: Event_Msg_Type, dtype: bool
