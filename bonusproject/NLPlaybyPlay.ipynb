# %%
import pandas as pd

# %%
from nba_py import game

# %%
from nba_py import Scoreboard

# %%
Scoreboard(month=3,day=30,year=2019).available()
# Out:
#       GAME_ID  PT_AVAILABLE
# 0  0021801136             1
# 1  0021801137             1
# 2  0021801140             1
# 3  0021801138             1
# 4  0021801141             1
# 5  0021801142             1
# 6  0021801139             1
# 7  0021801143             1
# 8  0021801144             1

# %%
from nba_py import

# %%
bdaygame = game.PlayByPlay(game_id='0021801137').info()

# %%
pd.concat([bdaygame['HOMEDESCRIPTION'] , bdaygame['VISITORDESCRIPTION']],axis=1)
# Out:
#                                        HOMEDESCRIPTION  \
# 0                                                 None
# 1            Jump Ball Allen vs. Baynes: Tip to Harris
# 2    Carroll Out of Bounds - Bad Pass Turnover Turn...
# 3                                                 None
# 4                         Kurucs REBOUND (Off:0 Def:1)
# 5                          MISS Carroll  3PT Jump Shot
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10               MISS Russell 25' 3PT Pullup Jump Shot
# 11                       Carroll REBOUND (Off:1 Def:0)
# 12                       MISS Carroll 2' Putback Layup
# 13                                                None
# 14                                                None
# 15     Kurucs  Alley Oop Layup (2 PTS) (Russell 1 AST)
# ...
