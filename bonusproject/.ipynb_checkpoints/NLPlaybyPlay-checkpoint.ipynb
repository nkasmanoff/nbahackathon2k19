# %%
import pandas as pd

# %%
from nba_py import game

# %%
game.PlayByPlay(game_id='0021801137').info()
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    0021801137         2            12                   0       1
# 1    0021801137         4            10                   0       1
# 2    0021801137         7             5                  45       1
# 3    0021801137         8             2                   3       1
# 4    0021801137         9             4                   0       1
# 5    0021801137        10             2                   1       1
# 6    0021801137        11             4                   0       1
# 7    0021801137        12             1                   1       1
# 8    0021801137        14             6                   1       1
# 9    0021801137        16             8                   0       1
# 10   0021801137        18             2                  79       1
# 11   0021801137        19             4                   0       1
# 12   0021801137        20             2                  72       1
# ...

# %%
from nba_py import Scoreboard

# %%
Scoreboard(month=3,day=30,year=2019).available()
# Out:
#       GAME_ID  PT_AVAILABLE
# 0  0021801136             1
# 1  0021801137             1
# 2  0021801140             1
# 3  0021801138             1
# 4  0021801141             1
# 5  0021801142             1
# 6  0021801139             1
# 7  0021801143             1
# 8  0021801144             1

# %%
from nba_py import
